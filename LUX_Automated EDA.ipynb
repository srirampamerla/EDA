# %% [markdown]
# # LUX - Automated EDA

# %%
# !pip install lux
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached matplotlib-3.9.0-cp39-cp39-win_amd64.whl (7.9 MB)
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# ...

# %% [markdown]
# To check the documentation- https://github.com/lux-org/lux

# %%
import pandas as pd
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/college.csv")
df
# Out:
#                                              Name PredominantDegree  \
# 0                        Alabama A & M University        Bachelor's
# 1             University of Alabama at Birmingham        Bachelor's
# 2             University of Alabama in Huntsville        Bachelor's
# 3                        Alabama State University        Bachelor's
# 4                       The University of Alabama        Bachelor's
# ...                                           ...               ...
# 1289        University of Connecticut-Avery Point        Bachelor's
# 1290           University of Connecticut-Stamford        Bachelor's
# 1291  California State University-Channel Islands        Bachelor's
# 1292              DigiPen Institute of Technology        Bachelor's
# 1293                           Neumont University        Bachelor's
#
#      HighestDegree        FundingModel           Region        Geography  \
# 0         Graduate              Public        Southeast    Mid-size City
# ...

# %% [markdown]
# Visualizations of dataframes beyond simple tables
#
# Lux preserves the Pandas dataframe semantics -- which means that you can apply any command from Pandas's API to the dataframes
#
# in Lux and expect the same behavior. For example, we can load the dataset via standard Pandas read_csv command.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lux-org/lux-datasets/master/data/employee.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# for best visualization #https://notebooks.gesis.org/binder/jupyter/user/lux-org-lux-binder-93m4rabu/lab/tree/demo/employee_demo.ipynb

# %%
# !pip install klib
# Out:
# ...
#   Using cached klib-1.1.2-py3-none-any.whl (22 kB)
# ...
#   Using cached matplotlib-3.9.0-cp39-cp39-win_amd64.whl (7.9 MB)
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# ...
#   Using cached screeninfo-0.8.1-py3-none-any.whl (12 kB)
# ...
#   Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\HP\\anaconda3\\Lib\\site-packages\\matplotlib\\ft2font.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\hp\anaconda3\lib\site-packages)
# ...
